# %%
import pipeline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm
filepath = "/Users/maxwellmb/tmp/liparis/Keck_AO_Mag_7_pt_5_Sci_Mag_5_01_PSF.fits"

plt.style.use('dark_background')

test = pipeline.Datacube(filepath)

# %%
test.select_lucky_images(selection_fraction=0.01)

# %%
test.lucky_indices.shape
# Out:
# (10,)

# %%
test.construct_lucky_image()

# %%
fig,axes = plt.subplots(1,2,figsize=(12,4))

vmin=100
vmax=np.max(test.lucky_image)


axes[0].imshow(np.median(test.data,axis=0),norm=LogNorm(vmin=vmin,vmax=vmax))
im = axes[1].imshow(test.lucky_image,norm=LogNorm(vmin=vmin,vmax=vmax))

axes[0].imshow(np.median(test.data,axis=0),vmin=vmin,vmax=vmax)
im = axes[1].imshow(test.lucky_image,vmin=vmin,vmax=vmax)


plt.colorbar(im,ax=axes[1])

# %%
plt.imshow(np.median(test.data,axis=0))
