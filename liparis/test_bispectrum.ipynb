# %%
import pipeline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm


plt.style.use('dark_background')

# %%
filepath = "/Users/maxwellmb/tmp/liparis/Keck_AO_Mag_7_pt_5_Sci_Mag_5_01_PSF.fits"
test = pipeline.Datacube(filepath)

# %%
import spatialstats as ss

from spatialstats.polyspectra import bispectrum

# %%
tst = bispectrum(test.data[0])

# %%
tst[2].shape
# Out:
# (40,)

# %%
test.data[0].shape
# Out:
# (80, 80)

# %%
plt.imshow(np.abs(tst[0]),norm=LogNorm())

# %%
plt.imshow(np.angle(tst[0]))
